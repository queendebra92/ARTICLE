# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize'] = (5, 5)

# %%
data=pd.read_csv('twelve_year_guardian_league_table.csv')

# %%
data
# Out:
#       Year  Rank   Institution  Satisfied_with_Course  \
# 0     2021    20      Aberdeen                     87
# 1     2020    34      Aberdeen                     86
# 2     2019    51      Aberdeen                     86
# 3     2018    46      Aberdeen                     86
# 4     2017    36      Aberdeen                     84
# ...    ...   ...           ...                    ...
# 1430  2014    94  York St John                     82
# 1431  2013    98  York St John                     84
# 1432  2012    96  York St John                     81
# 1433  2011    90  York St John                     80
# 1434  2022    84  York St John                     81
#
#       Satisfied_with_Teaching  Satisfied_with_Feedback  \
# 0                          86                       69
# 1                          87                       71
# 2                          88                       67
# 3                          88                       68
# ...

# %% [markdown]
# # EDA

# %%
#descriptive statistics
data.shape
# Out:
# (1435, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     1435 non-null   int64
#  1   Rank                     1435 non-null   int64
#  2   Institution              1435 non-null   object
#  3   Satisfied_with_Course    1435 non-null   int64
#  4   Satisfied_with_Teaching  1435 non-null   int64
#  5   Satisfied_with_Feedback  1435 non-null   int64
#  6   Student_to Staff_Ratio   1435 non-null   float64
#  7   Spend_per_Student        1435 non-null   float64
#  8   Average_Entry_Tariff     1435 non-null   float64
#  9   Value_Added_Score        1435 non-null   float64
#  10  Career_after_15 months   1435 non-null   int64
#  11  Continuation             1435 non-null   int64
#  12  Guardian Score           1435 non-null   float64
# dtypes: float64(5), int64(7), object(1)
# ...

# %%
data.isnull().sum()
# Out:
# Year                       0
# Rank                       0
# Institution                0
# Satisfied_with_Course      0
# Satisfied_with_Teaching    0
# Satisfied_with_Feedback    0
# Student_to Staff_Ratio     0
# Spend_per_Student          0
# Average_Entry_Tariff       0
# Value_Added_Score          0
# Career_after_15 months     0
# Continuation               0
# Guardian Score             0
# dtype: int64

# %%
data.describe()
# Out:
#              Year         Rank  Satisfied_with_Course  \
# count  1435.00000  1435.000000            1435.000000
# mean   2016.52892    60.149129              82.437631
# std       3.45660    34.527394               9.491359
# min    2011.00000     1.000000               0.000000
# 25%    2014.00000    30.000000              80.000000
# 50%    2017.00000    60.000000              84.000000
# 75%    2020.00000    90.000000              87.000000
# max    2022.00000   121.000000              94.000000
#
#        Satisfied_with_Teaching  Satisfied_with_Feedback  \
# count              1435.000000              1435.000000
# mean                 84.000697                69.004878
# std                   9.136002                 8.800396
# min                   0.000000                 0.000000
# 25%                  82.000000                66.000000
# 50%                  85.000000                70.000000
# 75%                  88.000000                73.000000
# ...

# %%
data['Satisfied_with_Course'].mean()
# Out:
# 82.43763066202091

# %%
data['Satisfied_with_Course'] = np.where(data['Satisfied_with_Course'] == 0.000000, data['Satisfied_with_Course'].mean(), data['Satisfied_with_Course'])
data['Satisfied_with_Teaching'] = np.where(data['Satisfied_with_Teaching'] == 0.000000, data['Satisfied_with_Teaching'].mean(), data['Satisfied_with_Teaching'])
data['Satisfied_with_Feedback'] = np.where(data['Satisfied_with_Feedback'] == 0.000000, data['Satisfied_with_Feedback'].mean(), data['Satisfied_with_Feedback'])
data['Student_to Staff_Ratio'] = np.where(data['Student_to Staff_Ratio'] == 0.000000, data['Student_to Staff_Ratio'].mean(), data['Student_to Staff_Ratio'])
data['Spend_per_Student'] = np.where(data['Spend_per_Student'] == 0.000000, data['Spend_per_Student'].mean(), data['Spend_per_Student'])
data['Average_Entry_Tariff'] = np.where(data['Average_Entry_Tariff'] == 0.000000, data['Average_Entry_Tariff'].mean(), data['Average_Entry_Tariff'])
data['Value_Added_Score'] = np.where(data['Value_Added_Score'] == 0.000000, data['Value_Added_Score'].mean(), data['Value_Added_Score'])
data['Career_after_15 months'] = np.where(data['Career_after_15 months'] == 0.000000, data['Career_after_15 months'].mean(), data['Career_after_15 months'])
data['Continuation'] = np.where(data['Continuation'] == 0.000000, data['Continuation'].mean(), data['Continuation'])
data['Guardian Score'] = np.where(data['Guardian Score'] == 0.000000, data['Guardian Score'].mean(), data['Guardian Score'])

data.head()
# Out:
#    Year  Rank Institution  Satisfied_with_Course  Satisfied_with_Teaching  \
# 0  2021    20    Aberdeen                   87.0                     86.0
# 1  2020    34    Aberdeen                   86.0                     87.0
# 2  2019    51    Aberdeen                   86.0                     88.0
# 3  2018    46    Aberdeen                   86.0                     88.0
# 4  2017    36    Aberdeen                   84.0                     86.0
#
#    Satisfied_with_Feedback  Student_to Staff_Ratio  Spend_per_Student  \
# 0                     69.0                    16.0                4.4
# 1                     71.0                    16.0                4.3
# 2                     67.0                    15.0                4.5
# 3                     68.0                    14.0                4.5
# 4                     65.0                    13.0                5.8
#
#    Average_Entry_Tariff  Value_Added_Score  Career_after_15 months  \
# ...

# %% [markdown]
# # Exploratory graphs

# %% [markdown]
# ### Data Distribution

# %%
#plot the histogram to see the distribution of the point data.
sns.displot(data, x="Guardian Score")

# %% [markdown]
# ### Correlation

# %%
corrMatrix = data.corr()
sns.set(rc = {'figure.figsize':(8,8)})
sns.heatmap(corrMatrix, annot = True, cmap= 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### charts comparing variables

# %%
sns.histplot(x='Year', data=data);

# %% [markdown]
# ### sorting the data into year

# %%
#2021 Guardian Scores
data_2021 =data.loc[data['Year'] == 2021]
data_2021=data_2021.head(18)
sns.set(rc = {'figure.figsize':(20,20)})
#sns.histplot(x='Institution', y ='Guardian Score', data=data_2021);
sns.scatterplot(x='Institution', y ='Guardian Score',  s= 100, palette="deep", data=data_2021);

# %%
#2020 Guardian Scores
data_2020 =data.loc[data['Year'] == 2020]
data_2020=data_2020.head(18)
sns.set(rc = {'figure.figsize':(20,20)})
#sns.histplot(x='Institution', y ='Guardian Score', data=data_2021);
sns.scatterplot(x='Institution', y ='Guardian Score',  s= 100, palette="deep", data=data_2020);

# %%
data_2021.shape
# Out:
# (121, 13)
